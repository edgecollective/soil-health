# %%
import pandas as pd
from matplotlib.pyplot import *
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
a=pd.read_csv("~/Downloads/battery.csv")

# %%
a.columns=['date','field','value']

# %%
a
# Out:
#                    date                         field    value
# 0    09/19/2019 - 17:36           Battery Voltage (V)     6.64
# 1    09/19/2019 - 17:42  Volumetric Water Content (%)     0.00
# 2    09/19/2019 - 17:42                 Soil Temp (C)    28.45
# 3    09/19/2019 - 17:42             Soil Permittivity     1.20
# 4    09/19/2019 - 17:42          Soil Bulk EC (uS/cm)     0.00
# ..                  ...                           ...      ...
# 992  09/20/2019 - 13:38                 Soil Temp (C)    38.64
# 993  09/20/2019 - 13:38             Soil Permittivity    27.49
# 994  09/20/2019 - 13:38          Soil Bulk EC (uS/cm)   562.87
# 995  09/20/2019 - 13:38    Soil Pore Water EC (uS/cm)  2381.84
# 996  09/20/2019 - 13:38           Battery Voltage (V)     6.49
#
# [997 rows x 3 columns]

# %%
h=a.iloc[::6]

# %%
h
# Out:
#                    date                field  value
# 0    09/19/2019 - 17:36  Battery Voltage (V)   6.64
# 6    09/19/2019 - 17:42  Battery Voltage (V)   6.66
# 12   09/19/2019 - 17:48  Battery Voltage (V)   6.64
# 18   09/19/2019 - 17:54  Battery Voltage (V)   6.63
# 24   09/19/2019 - 18:03  Battery Voltage (V)   6.64
# ..                  ...                  ...    ...
# 972  09/20/2019 - 13:13  Battery Voltage (V)   6.49
# 978  09/20/2019 - 13:19  Battery Voltage (V)   6.47
# 984  09/20/2019 - 13:26  Battery Voltage (V)   6.51
# 990  09/20/2019 - 13:32  Battery Voltage (V)   6.47
# 996  09/20/2019 - 13:38  Battery Voltage (V)   6.49
#
# [167 rows x 3 columns]

# %%
fig, ax = subplots()
fig.set_size_inches(15, 6)
#fig(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
#ax.xticks(rotation=70)
#h.plot(x='date',y='value',ax=ax,ylim=(.7,2.2),x_compat=True)
h.plot(x='date',y='value',style='.-',ax=ax,x_compat=True)
plt.xticks(rotation=86)
plt.ylabel("Battery (Volts)", labelpad=20)
#ax.xaxis.set_major_locator(mdates.HourLocator(interval=1))
#ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
#plt.gcf().autofmt_xdate()
ax.legend(['Battery (Volts)'])
ax.xaxis.labelpad = 20
#hours = mdates.HourLocator(interval = 1)
#h_fmt = mdates.DateFormatter('%H:%M:%S')
#ax.xaxis.set_major_locator(hours)
#ax.xaxis.set_major_formatter(h_fmt)
#fig.autofmt_xdate()
#plt.show()
#ax.xaxis.set_major_locator(mdates.HourLocator(interval=1))
#ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
#ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
#plt.gcf().autofmt_xdate()
#plt.show()
#plt.axhline(y=1.6, color='r', linestyle='-')
#plt.axhline(y=1.7, color='r', linestyle='-')
#plt.axhline(y=1.98, color='r', linestyle='-')

# %% [markdown]
# try this next: https://stackoverflow.com/questions/48790378/how-to-get-ticks-every-hour
